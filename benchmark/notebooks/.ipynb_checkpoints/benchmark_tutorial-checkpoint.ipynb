# %% [markdown]
# # CrossCell Performance Benchmark
#
# This notebook runs a complete performance benchmark comparing CrossCell against other single-cell data conversion tools:
#
# | Tool | Language | RDS→H5AD | H5AD→RDS |
# |------|----------|----------|----------|
# | **CrossCell** | Rust CLI | ✅ | ✅ |
# | **Zellkonverter** | R | ✅ | ✅ |
# | **anndataR** | R | ✅ | ✅ |
# | **convert2anndata** | R | ✅ | ❌ |
# | **easySCF** | R + Python | ✅ | ❌ |
#
# **Datasets:** 55 test cases from SeuratData, scanpy, scvelo, squidpy, and CELLxGENE (1.4k–73k cells).
#
# **Metrics:** Conversion time (seconds), peak memory (MB), output file size (MB).
#
# ---
#
# ## Prerequisites & Environment Setup
#
# This benchmark runs inside a pre-built Docker image that contains all required tools.
# You only need **Docker** installed on your machine.
#
# ### Option A: Pull from Docker Hub (Recommended)
#
# ```bash
# docker pull crosscell/benchmark:latest
# ```
#
# Then start the Jupyter notebook server:
#
# ```bash
# mkdir -p data/generated benchmark/results benchmark/notebooks
#
# docker run -it --rm \
#   -p 8888:8888 \
#   -v $(pwd)/data:/benchmark/data \
#   -v $(pwd)/benchmark/results:/benchmark/results \
#   -v $(pwd)/benchmark/notebooks:/benchmark/notebooks \
#   crosscell/benchmark:latest \
#   jupyter notebook --ip=0.0.0.0 --port=8888 --no-browser --allow-root \
#     --NotebookApp.token='' --NotebookApp.password=''
# ```
#
# Open http://localhost:8888 and navigate to this notebook.

# %% [markdown]
# ### Option B: Build from Source
#
# ```bash
# git clone https://github.com/crosscell/crosscell.git
# cd crosscell
# cargo build --release
# cp target/release/crosscell benchmark/
# docker-compose -f benchmark/docker-compose.benchmark.yml build notebook
# docker-compose -f benchmark/docker-compose.benchmark.yml up notebook
# ```
#
# ### What's Inside the Docker Image
#
# | Component | Version | Purpose |
# |-----------|---------|--------|
# | R | 4.5.x | R runtime |
# | Python | 3.12 | Python runtime (venv at `/opt/venv`) |
# | Seurat | 5.x | Seurat V5 (also reads V4 objects) |
# | zellkonverter | 1.20+ | Bioconductor conversion tool |
# | anndataR | 1.0+ | Bioconductor AnnData interface |
# | convert2anndata | 0.2+ | settylab conversion tool |
# | easySCFr / easySCFpy | latest | easySCF R + Python packages |
# | anndata (Python) | 0.12.3 | AnnData Python library |
# | CrossCell | 0.1.x | Rust CLI binary |
# | Jupyter + IRkernel | latest | Notebook server with R kernel |
# | matplotlib | latest | Plotting |
#
# ### Container Directory Layout
#
# ```
# /benchmark/
# ├── data/generated/    # Dataset files (.rds, .h5ad)
# ├── config/            # benchmark_testcases.json, datasets.json
# ├── results/           # Benchmark output JSON files
# ├── scripts/           # Benchmark runner scripts (read-only)
# ├── notebooks/         # This notebook
# └── test_data/         # Unit test data (read-only)
# ```
#
# ### System Requirements
#
# - **RAM:** 8 GB minimum, 16 GB recommended
# - **Disk:** ~5 GB for Docker image + ~4 GB for datasets
# - **Time:** Full benchmark ~30–60 min

# %% [markdown]
# ---
# ## Step 0: Environment Check

# %%
import subprocess, sys, os, json, time, re, glob, shutil
from pathlib import Path
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')
os.environ['PYTHONWARNINGS'] = 'ignore'

def run(cmd, timeout=300):
    r = subprocess.run(cmd, capture_output=True, text=True, timeout=timeout)
    return r.returncode, r.stdout, r.stderr

def run_r(script, timeout=300):
    wrapped = f'suppressWarnings(suppressMessages({{\n{script.strip()}\n}}))'
    return run(['Rscript', '-e', wrapped], timeout=timeout)

print(f'Python: {sys.version.split()[0]}')
rc, out, _ = run(['crosscell', '--version'])
print(f'CrossCell: {out.strip()}' if rc == 0 else '❌ CrossCell not found')
rc, out, _ = run_r('cat(R.version.string)')
print(f'{out.strip()}' if rc == 0 else '❌ R not found')
for pkg in ['zellkonverter', 'anndataR', 'convert2anndata', 'easySCFr', 'Seurat']:
    rc, out, _ = run_r(f"cat(as.character(packageVersion('{pkg}')))")
    print(f'  {pkg}: {out.strip()}' if rc == 0 else f'  ❌ {pkg}: not installed')
import anndata; print(f'  anndata (Python): {anndata.__version__}')
print('\n✅ Environment ready')
# Out:
# Python: 3.12.12
# CrossCell: crosscell 0.1.0
# R version 4.5.2 (2025-10-31)
#   zellkonverter: 1.20.1
#   anndataR: 1.0.1
#   convert2anndata: 0.2.0
#   easySCFr: 0.2.2.7
#   Seurat: 5.4.0
#   anndata (Python): 0.12.3
#
# ✅ Environment ready

# %% [markdown]
# ---
# ## Step 1: Download Datasets from Zenodo
#
# All benchmark datasets (RDS + H5AD) are archived on Zenodo.
# This cell downloads and extracts them. Existing files are skipped.
#
# > **TODO:** Replace `ZENODO_RECORD_ID` below with the actual Zenodo deposit ID once uploaded.

# %%
DATA_DIR = '/benchmark/data/generated'
os.makedirs(DATA_DIR, exist_ok=True)

# ── Zenodo configuration ──
ZENODO_RECORD_ID = '00000000'  # TODO: fill in real record ID
ZENODO_BASE = f'https://zenodo.org/records/{ZENODO_RECORD_ID}/files'

# Split archives — download only what you need
ARCHIVES = [
    'seurat_v4_datasets.tar.gz',
    'seurat_v5_datasets.tar.gz',
    'h5ad_small_datasets.tar.gz',
    'h5ad_spatial_datasets.tar.gz',
    'h5ad_cellxgene_datasets.tar.gz',
]

# Check if data already exists
rds_files = glob.glob(os.path.join(DATA_DIR, '*.rds'))
h5ad_files = glob.glob(os.path.join(DATA_DIR, '*.h5ad'))
print(f'Existing data: {len(rds_files)} .rds, {len(h5ad_files)} .h5ad')

if len(rds_files) >= 40 and len(h5ad_files) >= 10:
    print('\u2705 Datasets already present, skipping download.')
else:
    for archive in ARCHIVES:
        url = f'{ZENODO_BASE}/{archive}'
        local = f'/tmp/{archive}'
        print(f'\n\U0001f4e5 Downloading {archive}...')
        rc, out, err = run(
            ['curl', '-L', '-C', '-', '--retry', '5', '--retry-delay', '3',
             '-o', local, url],
            timeout=3600
        )
        if rc == 0 and os.path.exists(local):
            size_mb = os.path.getsize(local) / 1024 / 1024
            print(f'  \u2705 Downloaded: {size_mb:.0f} MB')
            print(f'  \U0001f4e6 Extracting...')
            rc2, _, err2 = run(['tar', 'xzf', local, '-C', '/benchmark'], timeout=600)
            if rc2 == 0:
                os.remove(local)
                print(f'  \u2705 Extracted')
            else:
                print(f'  \u274c Extraction failed: {err2[:300]}')
        else:
            print(f'  \u274c Download failed (rc={rc}): {err[:300]}')

    rds_files = glob.glob(os.path.join(DATA_DIR, '*.rds'))
    h5ad_files = glob.glob(os.path.join(DATA_DIR, '*.h5ad'))
    print(f'\n\u2705 Total: {len(rds_files)} .rds, {len(h5ad_files)} .h5ad')
# Out:
# Existing data: 44 .rds, 13 .h5ad
# ✅ Datasets already present, skipping download.

# %% [markdown]
# ### Verify downloaded data

# %%
rds_files = sorted(glob.glob(os.path.join(DATA_DIR, '*.rds')))
h5ad_files = sorted(glob.glob(os.path.join(DATA_DIR, '*.h5ad')))

print(f'RDS files:  {len(rds_files):3d}  (expected >= 42)')
print(f'H5AD files: {len(h5ad_files):3d}  (expected >= 13)')

# Spot-check key files
key_files = [
    'seurat_v4_pbmc3k_raw.rds', 'seurat_v5_pbmc3k_raw.rds',
    'seurat_v4_hcabm40k_raw.rds', 'seurat_v5_ssHippo_raw.rds',
    'scanpy_pbmc3k.h5ad', 'cellxgene_brain_40k.h5ad',
    'scvelo_pancreas.h5ad', 'squidpy_merfish.h5ad',
]
print(f'\nSpot check ({len(key_files)} key files):')
all_ok = True
for name in key_files:
    path = os.path.join(DATA_DIR, name)
    if os.path.exists(path):
        size = os.path.getsize(path) / 1024 / 1024
        print(f'  \u2705 {name:45s} {size:8.1f} MB')
    else:
        print(f'  \u274c {name:45s} MISSING')
        all_ok = False

if all_ok:
    print('\n\u2705 All key files present.')
else:
    print('\n\u26a0\ufe0f Some files missing. Check download or Zenodo archive.')
# Out:
# RDS files:   44  (expected >= 42)
# H5AD files:  13  (expected >= 13)
#
# Spot check (8 key files):
#   ✅ seurat_v4_pbmc3k_raw.rds                           9.8 MB
#   ✅ seurat_v5_pbmc3k_raw.rds                           4.9 MB
#   ✅ seurat_v4_hcabm40k_raw.rds                       180.2 MB
#   ✅ seurat_v5_ssHippo_raw.rds                         47.8 MB
#   ✅ scanpy_pbmc3k.h5ad                                 5.6 MB
#   ✅ cellxgene_brain_40k.h5ad                         464.1 MB
#   ✅ scvelo_pancreas.h5ad                              50.0 MB
#   ✅ squidpy_merfish.h5ad                              49.2 MB
#
# ✅ All key files present.

# %% [markdown]
# ---
# ## Step 2: Inspect Dataset Summary
#
# List all input datasets with their file sizes. These are the source files used for conversion, not the output sizes.

# %%
import pandas as pd
rows = []
for f in sorted(glob.glob(os.path.join(DATA_DIR, '*'))):
    name = os.path.basename(f)
    ext = os.path.splitext(name)[1]
    if ext not in ('.rds', '.h5ad'): continue
    size_mb = os.path.getsize(f) / 1024 / 1024
    rows.append({'file': name, 'format': ext, 'input_size_mb': round(size_mb, 1)})
df_data = pd.DataFrame(rows)
print(f'Total: {len(df_data)} files  |  .rds: {len(df_data[df_data.format==".rds"])}  |  .h5ad: {len(df_data[df_data.format==".h5ad"])}  |  {df_data.input_size_mb.sum():.0f} MB')
df_data
# Out:
# Total: 57 files  |  .rds: 44  |  .h5ad: 13  |  7226 MB
#                                         file format  input_size_mb
# 0                   cellxgene_brain_40k.h5ad  .h5ad          464.1
# 1                   cellxgene_heart_23k.h5ad  .h5ad          164.3
# 2                    cellxgene_pbmc_15k.h5ad  .h5ad           71.0
# 3                         scanpy_pbmc3k.h5ad  .h5ad            5.6
# 4               scanpy_pbmc3k_processed.h5ad  .h5ad           23.5
# 5                   scvelo_dentategyrus.h5ad  .h5ad           23.7
# 6                       scvelo_pancreas.h5ad  .h5ad           50.0
# 7             seurat_v4_bmcite_processed.rds   .rds          244.6
# 8   seurat_v4_bmcite_processed.roundtrip.rds   .rds          141.4
# 9                   seurat_v4_bmcite_raw.rds   .rds          167.1
# 10              seurat_v4_cbmc_processed.rds   .rds           54.9
# 11                    seurat_v4_cbmc_raw.rds   .rds           34.0
# 12   seurat_v4_celegans.embryo_processed.rds   .rds           34.3
# 13         seurat_v4_celegans.embryo_raw.rds   .rds           20.8
# 14          seurat_v4_hcabm40k_processed.rds   .rds          290.9
# 15                seurat_v4_hcabm40k_raw.rds   .rds          180.2
# 16              seurat_v4_ifnb_processed.rds   .rds           72.4
# 17                    seurat_v4_ifnb_raw.rds   .rds           40.3
# 18             seurat_v4_panc8_processed.rds   .rds          327.2
# 19                   seurat_v4_panc8_raw.rds   .rds          275.3
# 20            seurat_v4_pbmc3k_processed.rds   .rds           19.1
# 21                  seurat_v4_pbmc3k_raw.rds   .rds            9.8
# 22           seurat_v4_pbmcsca_processed.rds   .rds          165.5
# 23                 seurat_v4_pbmcsca_raw.rds   .rds          121.4
# 24           seurat_v4_ssHippo_processed.rds   .rds          162.1
# 25                 seurat_v4_ssHippo_raw.rds   .rds           94.1
# 26               seurat_v4_stxKidney_raw.rds   .rds           37.8
# 27       seurat_v4_thp1.eccite_processed.rds   .rds          439.3
# 28             seurat_v4_thp1.eccite_raw.rds   .rds          309.5
# 29   seurat_v4_thp1.eccite_raw.roundtrip.rds   .rds          132.0
# 30            seurat_v5_bmcite_processed.rds   .rds          203.2
# 31                  seurat_v5_bmcite_raw.rds   .rds           59.9
# 32              seurat_v5_cbmc_processed.rds   .rds           54.2
# 33                    seurat_v5_cbmc_raw.rds   .rds           16.8
# 34   seurat_v5_celegans.embryo_processed.rds   .rds           33.9
# 35         seurat_v5_celegans.embryo_raw.rds   .rds           10.5
# 36          seurat_v5_hcabm40k_processed.rds   .rds          290.0
# 37                seurat_v5_hcabm40k_raw.rds   .rds           90.4
# 38              seurat_v5_ifnb_processed.rds   .rds           72.2
# 39                    seurat_v5_ifnb_raw.rds   .rds           20.2
# 40             seurat_v5_panc8_processed.rds   .rds          326.9
# 41                   seurat_v5_panc8_raw.rds   .rds          137.7
# 42            seurat_v5_pbmc3k_processed.rds   .rds           18.9
# 43                  seurat_v5_pbmc3k_raw.rds   .rds            4.9
# 44           seurat_v5_pbmcsca_processed.rds   .rds          164.7
# 45                 seurat_v5_pbmcsca_raw.rds   .rds           61.0
# 46           seurat_v5_ssHippo_processed.rds   .rds          161.1
# 47                 seurat_v5_ssHippo_raw.rds   .rds           47.8
# 48               seurat_v5_stxKidney_raw.rds   .rds           18.4
# 49       seurat_v5_thp1.eccite_processed.rds   .rds          436.6
# 50             seurat_v5_thp1.eccite_raw.rds   .rds          154.0
# 51                          squidpy_imc.h5ad  .h5ad            1.5
# 52                      squidpy_merfish.h5ad  .h5ad           49.2
# 53                      squidpy_mibitof.h5ad  .h5ad           19.3
# 54                      squidpy_seqfish.h5ad  .h5ad           30.7
# 55                   squidpy_slideseqv2.h5ad  .h5ad          251.3
# 56                   squidpy_visium_hne.h5ad  .h5ad          314.1

# %% [markdown]
# ---
# ## Step 3: Load Test Matrix & Define Benchmark Engine

# %%
MATRIX_FILE = '/benchmark/config/benchmark_testcases.json'
RESULTS_DIR = '/benchmark/results'
OUTPUT_TMP_DIR = '/tmp/benchmark_output'
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(OUTPUT_TMP_DIR, exist_ok=True)

with open(MATRIX_FILE) as f:
    matrix = json.load(f)

s = matrix['summary']
print(f'Test matrix v{matrix["version"]}')
print(f'Tools: {", ".join(t["name"] for t in matrix["tools"])}')
print(f'Test cases: {s["total_test_cases"]} (RDS→H5AD: {s["rds_to_h5ad_count"]}, H5AD→RDS: {s["h5ad_to_rds_count"]})')
print(f'Scale: {s["scale_distribution"]}')
# Out:
# Test matrix v2.0
# Tools: crosscell, zellkonverter, anndataR, convert2anndata, easySCF
# Test cases: 55 (RDS→H5AD: 42, H5AD→RDS: 13)
# Scale: {'rds_to_h5ad': {'small': 6, 'medium': 16, 'large': 20}, 'h5ad_to_rds': {'small': 7, 'medium': 2, 'large': 4}}

# %% [markdown]
# ---
# ## Step 4: Define Benchmark Engine
#
# Tool command generators, measurement functions, and the benchmark runner — all inlined from `run_benchmark.py`.

# %%
# ── Path helpers ──
def get_output_path(test_id, tool, direction):
    ext = 'h5ad' if direction == 'rds_to_h5ad' else 'rds'
    return os.path.join(OUTPUT_TMP_DIR, f'{tool}_{test_id}.{ext}')

def resolve_input_path(raw_path):
    if raw_path.startswith('data/'):
        return os.path.join('/benchmark', raw_path)
    return raw_path

# ── Tool command generators ──
def cmd_crosscell(inp, out, direction):
    fmt = 'anndata' if direction == 'rds_to_h5ad' else 'seurat'
    return ['crosscell', 'convert', '-i', inp, '-o', out, '-f', fmt]

def cmd_zellkonverter(inp, out, direction):
    if direction == 'rds_to_h5ad':
        s = f'''
library(Seurat); library(zellkonverter); library(SingleCellExperiment)
obj <- readRDS("{inp}"); obj <- UpdateSeuratObject(obj)
sce <- as.SingleCellExperiment(obj); writeH5AD(sce, "{out}")
'''
    else:
        s = f'''
library(zellkonverter); library(Seurat); library(SingleCellExperiment)
fix_dn <- function(sce) {{
  if (is.null(rownames(sce))||length(rownames(sce))==0) {{
    if ("_index" %in% names(rowData(sce))) rownames(sce)<-rowData(sce)[["_index"]]
    else if ("gene_ids" %in% names(rowData(sce))) rownames(sce)<-rowData(sce)[["gene_ids"]]
    else rownames(sce)<-paste0("Gene_",seq_len(nrow(sce)))
  }}
  if (is.null(colnames(sce))||length(colnames(sce))==0) {{
    if ("_index" %in% names(colData(sce))) colnames(sce)<-colData(sce)[["_index"]]
    else colnames(sce)<-paste0("Cell_",seq_len(ncol(sce)))
  }}
  sce
}}
ok<-FALSE
tryCatch({{ sce<-readH5AD("{inp}",reader="R"); sce<-fix_dn(sce)
  obj<-as.Seurat(sce,counts="X",data=NULL); saveRDS(obj,"{out}"); ok<-TRUE
}}, error=function(e) cat("R reader failed:",conditionMessage(e),"\\n"))
if (!ok) {{
  Sys.setenv(RETICULATE_PYTHON="/opt/venv/bin/python3")
  library(reticulate); use_python("/opt/venv/bin/python3",required=TRUE)
  ad<-import("anndata"); adata<-ad$read_h5ad("{inp}")
  sce<-AnnData2SCE(adata); sce<-fix_dn(sce)
  obj<-as.Seurat(sce,counts="X",data=NULL); saveRDS(obj,"{out}")
}}
'''
    return ['Rscript', '-e', s.strip()]

def cmd_anndatar(inp, out, direction):
    if direction == 'rds_to_h5ad':
        s = f'library(anndataR);library(Seurat);obj<-readRDS("{inp}");obj<-UpdateSeuratObject(obj);if(file.exists("{out}"))file.remove("{out}");ad<-as_AnnData(obj);write_h5ad(ad,"{out}")'
    else:
        s = f'library(anndataR);library(Seurat);ad<-read_h5ad("{inp}");obj<-ad$as_Seurat();saveRDS(obj,"{out}")'
    return ['Rscript', '-e', s]

def cmd_convert2anndata(inp, out, direction):
    if direction != 'rds_to_h5ad': return None
    s = f'library(convert2anndata);library(Seurat);obj<-readRDS("{inp}");obj<-UpdateSeuratObject(obj);sce<-convert_seurat_to_sce(obj);ad<-convert_to_anndata(sce);anndata::write_h5ad(ad,"{out}")'
    return ['Rscript', '-e', s]

def cmd_easyscf(inp, out, direction):
    if direction != 'rds_to_h5ad': return None
    s = f'library(easySCFr);library(Seurat);obj<-readRDS("{inp}");obj<-UpdateSeuratObject(obj);saveH5(obj,"{out}")'
    return ['Rscript', '-e', s]

TOOL_COMMANDS = {
    'crosscell': cmd_crosscell,
    'zellkonverter': cmd_zellkonverter,
    'anndataR': cmd_anndatar,
    'convert2anndata': cmd_convert2anndata,
    'easySCF': cmd_easyscf,
}

print('✅ Benchmark engine loaded:', list(TOOL_COMMANDS.keys()))
# Out:
# ✅ Benchmark engine loaded: ['crosscell', 'zellkonverter', 'anndataR', 'convert2anndata', 'easySCF']

# %%
# ── Measurement ──
def split_time_stderr(stderr):
    marker = '\tCommand being timed:'
    idx = stderr.find(marker)
    if idx >= 0: return stderr[:idx].rstrip(), stderr[idx:]
    return stderr, ''

def run_with_measurement(cmd, timeout=600):
    time_cmd = ['/usr/bin/time', '-v'] + cmd
    start = time.time()
    try:
        result = subprocess.run(time_cmd, capture_output=True, text=True, timeout=timeout)
        elapsed = time.time() - start
    except subprocess.TimeoutExpired:
        return False, timeout, 0, 'TIMEOUT'
    tool_stderr, time_stats = split_time_stderr(result.stderr)
    peak_mem_mb = 0
    m = re.search(r'Maximum resident set size \(kbytes\): (\d+)', time_stats)
    if m: peak_mem_mb = int(m.group(1)) / 1024.0
    error_output = tool_stderr
    if result.returncode != 0 and result.stdout:
        error_output = result.stdout.rstrip() + '\n' + tool_stderr
    return result.returncode == 0, elapsed, peak_mem_mb, error_output

def get_file_size_mb(path):
    try: return os.path.getsize(path) / (1024*1024)
    except OSError: return 0

# ── Single test runner ──
def run_single_test(tool_name, case, direction, runs=3, timeout=600):
    test_id = case['id']
    inp = resolve_input_path(case['input'])
    out = get_output_path(test_id, tool_name, direction)
    if not os.path.exists(inp):
        return {'test_id': test_id, 'status': 'skipped', 'reason': f'input not found: {inp}'}
    cmd_fn = TOOL_COMMANDS.get(tool_name)
    if not cmd_fn:
        return {'test_id': test_id, 'status': 'error', 'reason': f'unknown tool: {tool_name}'}
    cmd = cmd_fn(inp, out, direction)
    if cmd is None:
        return {'test_id': test_id, 'status': 'skipped', 'reason': f'{tool_name} does not support {direction}'}
    times, mems = [], []
    for i in range(runs):
        if os.path.exists(out): os.remove(out)
        ok, elapsed, peak, stderr = run_with_measurement(cmd, timeout)
        if not ok:
            return {'test_id': test_id, 'dataset': case.get('dataset',''), 'direction': direction,
                    'status': 'failed', 'error': stderr[:3000], 'run': i+1}
        times.append(elapsed); mems.append(peak)
    times.sort(); mems.sort()
    return {
        'test_id': test_id, 'dataset': case.get('dataset',''), 'direction': direction,
        'status': 'success',
        'conversion_time_seconds': round(times[len(times)//2], 3),
        'peak_memory_mb': round(mems[len(mems)//2], 1),
        'output_file_size_mb': round(get_file_size_mb(out), 2),
        'all_times': [round(t,3) for t in times],
        'all_mems': [round(m,1) for m in mems],
        'n_cells': case.get('n_cells'), 'n_genes': case.get('n_genes'),
        'scale': case.get('scale'), 'seurat_version': case.get('seurat_version',''),
        'type': case.get('type',''),
    }

print('✅ Measurement functions loaded')
# Out:
# ✅ Measurement functions loaded

# %%
def run_tool_benchmark(tool_name, runs=3, timeout=600):
    """Run benchmark for a single tool across all test cases. Returns results dict."""
    results = {
        'tool': tool_name,
        'timestamp': time.strftime('%Y-%m-%dT%H:%M:%SZ', time.gmtime()),
        'config': {'runs_per_test': runs, 'timeout_seconds': timeout},
        'rds_to_h5ad': [], 'h5ad_to_rds': [], 'summary': {},
    }
    tool_directions = []
    for t in matrix['tools']:
        if t['name'] == tool_name:
            tool_directions = t.get('directions', [])
    total = success = failed = skipped = 0
    for d in ['rds_to_h5ad', 'h5ad_to_rds']:
        if d not in tool_directions:
            print(f'  ⏭️  {tool_name} does not support {d}')
            continue
        cases = matrix['test_cases'].get(d, [])
        print(f'\n  {d} ({len(cases)} test cases)')
        print(f'  {"─"*95}')
        print(f'  {"#":>5}  {"test_id":40s} {"cells":>6} × {"genes":<6}       {"time":>6}  {"peak_mem":>8}  {"out_size":>8}')
        print(f'  {"─"*95}')
        for i, case in enumerate(cases):
            total += 1
            tid = case['id']
            nc = case.get('n_cells','?'); ng = case.get('n_genes','?')
            print(f'  [{i+1:2d}/{len(cases)}] {tid:40s} {nc:>6} × {ng:<6}', end=' ')
            r = run_single_test(tool_name, case, d, runs, timeout)
            if r['status'] == 'success':
                success += 1
                print(f'✅ {r["conversion_time_seconds"]:6.2f}s  {r["peak_memory_mb"]:7.0f} MB  {r["output_file_size_mb"]:7.1f} MB')
            elif r['status'] == 'skipped':
                skipped += 1
                print(f'⏭️  {r.get("reason","")[:60]}')
            else:
                failed += 1
                print(f'❌ {r.get("error","")[:80]}')
            results[d].append(r)
    results['summary'] = {'total': total, 'success': success, 'failed': failed, 'skipped': skipped}
    # Save to JSON
    out_file = os.path.join(RESULTS_DIR, f'{tool_name}.json')
    with open(out_file, 'w') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)
    print(f'\n  📊 {tool_name}: {success}/{total} success, {failed} failed, {skipped} skipped')
    print(f'  💾 Saved: {out_file}')
    return results

# Store all results
all_results = {}
TOOLS = list(TOOL_COMMANDS.keys())
print('✅ Runner ready. Tools:', TOOLS)
# Out:
# ✅ Runner ready. Tools: ['crosscell', 'zellkonverter', 'anndataR', 'convert2anndata', 'easySCF']

# %% [markdown]
# ---
# ## Step 5: Benchmark — CrossCell
#
# Rust CLI, supports both RDS→H5AD and H5AD→RDS.

# %%
t0 = time.time()
all_results['crosscell'] = run_tool_benchmark('crosscell', runs=3, timeout=600)
print(f'\n⏱️ Total: {time.time()-t0:.0f}s')
# Out:
#   rds_to_h5ad (42 test cases)
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#       #  test_id                                   cells × genes          time  peak_mem  out_size
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#   [ 1/42] v4_pbmc3k_raw                              2700 × 13714  ✅   0.46s      152 MB     26.2 MB
#   [ 2/42] v4_pbmc3k_processed                        2700 × 13714  ✅   0.68s      232 MB     27.3 MB
#   [ 3/42] v5_pbmc3k_raw                              2700 × 13714  ✅   0.32s      114 MB     26.2 MB
#   [ 4/42] v5_pbmc3k_processed                        2700 × 13714  ✅   0.79s      246 MB     27.3 MB
#   [ 5/42] v4_stxKidney_raw                           1438 × 31053  ✅   1.73s      566 MB     91.9 MB
#   [ 6/42] v5_stxKidney_raw                           1438 × 31053  ✅   1.15s      409 MB     91.9 MB
#   [ 7/42] v4_celegans_raw                            6188 × 20222  ✅   1.12s      317 MB     58.7 MB
#   [ 8/42] v4_celegans_processed                      6188 × 20222  ✅   1.51s      480 MB     61.2 MB
#   [ 9/42] v5_celegans_raw                            6188 × 20222  ✅   0.96s      257 MB     58.7 MB
#   [10/42] v5_celegans_processed                      6188 × 20222  ✅   2.00s      520 MB     61.2 MB
#   [11/42] v4_cbmc_raw                                8617 × 20501  ✅   2.31s      580 MB     95.4 MB
#   [12/42] v4_cbmc_processed                          8617 × 20501  ✅   3.07s      717 MB     98.9 MB
#   [13/42] v5_cbmc_raw                                8617 × 20501  ✅   1.29s      420 MB     94.7 MB
#   [14/42] v5_cbmc_processed                          8617 × 20501  ✅   3.07s      829 MB     98.2 MB
#   [15/42] v4_ifnb_raw                               13999 × 14053  ✅   2.45s      584 MB    113.5 MB
#   [16/42] v4_ifnb_processed                         13999 × 14053  ✅   3.94s      966 MB    119.1 MB
#   [17/42] v5_ifnb_raw                               13999 × 14053  ✅   1.74s      465 MB    113.5 MB
#   [18/42] v5_ifnb_processed                         13999 × 14053  ✅   4.12s      996 MB    119.1 MB
#   [19/42] v4_panc8_raw                              14890 × 34363  ✅  16.42s     3004 MB    596.1 MB
#   [20/42] v4_panc8_processed                        14890 × 34363  ✅  18.23s     3299 MB    602.2 MB
#   [21/42] v5_panc8_raw                              14890 × 34363  ✅  12.15s     2399 MB    596.1 MB
#   [22/42] v5_panc8_processed                        14890 × 34363  ✅  19.48s     4072 MB    602.2 MB
#   [23/42] v4_thp1_raw                               20729 × 18649  ✅  25.86s     4148 MB    818.3 MB
#   [24/42] v4_thp1_processed                         20729 × 18649  ✅  24.30s     4536 MB    826.7 MB
#   [25/42] v5_thp1_raw                               20729 × 18649  ✅  15.74s     3204 MB    798.2 MB
#   [26/42] v5_thp1_processed                         20729 × 18649  ✅  27.81s     5453 MB    806.7 MB
#   [27/42] v4_bmcite_raw                             30672 × 17009  ✅   8.46s     1853 MB    336.2 MB
#   [28/42] v4_bmcite_processed                       30672 × 17009  ✅  11.08s     2624 MB    348.6 MB
#   [29/42] v5_bmcite_raw                             30672 × 17009  ✅   5.04s     1289 MB    318.6 MB
#   [30/42] v5_bmcite_processed                       30672 × 17009  ✅  12.40s     2595 MB    331.0 MB
#   [31/42] v4_pbmcsca_raw                            31021 × 33694  ✅   7.23s     1652 MB    325.2 MB
#   [32/42] v4_pbmcsca_processed                      31021 × 33694  ✅  10.46s     2439 MB    337.7 MB
#   [33/42] v5_pbmcsca_raw                            31021 × 33694  ✅   5.14s     1320 MB    325.2 MB
#   [34/42] v5_pbmcsca_processed                      31021 × 33694  ✅  11.39s     2654 MB    337.7 MB
#   [35/42] v4_hcabm40k_raw                           40000 × 17369  ✅  11.51s     2352 MB    462.3 MB
#   [36/42] v4_hcabm40k_processed                     40000 × 17369  ✅  16.76s     3297 MB    478.4 MB
#   [37/42] v5_hcabm40k_raw                           40000 × 17369  ✅   8.50s     1877 MB    462.3 MB
#   [38/42] v5_hcabm40k_processed                     40000 × 17369  ✅  17.39s     3720 MB    478.4 MB
#   [39/42] v4_ssHippo_raw                            53173 × 23264  ✅   8.50s     1344 MB    256.9 MB
#   [40/42] v4_ssHippo_processed                      53173 × 23264  ✅  12.23s     2945 MB    278.4 MB
#   [41/42] v5_ssHippo_raw                            53173 × 23264  ✅   6.03s     1072 MB    256.9 MB
#   [42/42] v5_ssHippo_processed                      53173 × 23264  ✅  12.38s     2912 MB    278.4 MB
#
#   h5ad_to_rds (13 test cases)
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#       #  test_id                                   cells × genes          time  peak_mem  out_size
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#   [ 1/13] scanpy_pbmc3k                              2700 × 32738  ✅   2.97s      153 MB      4.8 MB
#   [ 2/13] scanpy_pbmc3k_processed                    2638 × 1838   ✅   8.69s      254 MB     21.4 MB
#   [ 3/13] scvelo_pancreas                            3696 × 27998  ✅  28.23s      901 MB     45.8 MB
#   [ 4/13] scvelo_dentategyrus                        2930 × 13913  ✅  13.70s      458 MB     22.0 MB
#   [ 5/13] squidpy_imc                                4668 × 34     ✅   0.41s       17 MB      0.8 MB
#   [ 6/13] squidpy_mibitof                            3309 × 36     ✅   0.48s       27 MB      1.5 MB
#   [ 7/13] squidpy_visium_hne                         2688 × 18078  ✅  20.43s      919 MB     36.0 MB
#   [ 8/13] cellxgene_pbmc_15k                        14783 × 17222  ✅  20.00s      858 MB     35.7 MB
#   [ 9/13] squidpy_seqfish                           19416 × 351    ✅   2.31s       98 MB      3.6 MB
#   [10/13] cellxgene_heart_23k                       23483 × 32330  ✅  44.08s     2076 MB     82.7 MB
#   [11/13] cellxgene_brain_40k                       40165 × 58232  ✅ 296.94s    11900 MB    495.9 MB
#   [12/13] squidpy_slideseqv2                        41786 × 4000   ✅  10.34s      334 MB     20.6 MB
#   [13/13] squidpy_merfish                           73655 × 161    ✅   7.16s      301 MB     19.5 MB
#
#   📊 crosscell: 55/55 success, 0 failed, 0 skipped
#   💾 Saved: /benchmark/results/crosscell.json
#
# ⏱️ Total: 2455s

# %% [markdown]
# ---
# ## Step 6: Benchmark — Zellkonverter
#
# R/Bioconductor, uses basilisk for Python interop. Supports both directions.

# %%
t0 = time.time()
all_results['zellkonverter'] = run_tool_benchmark('zellkonverter', runs=3, timeout=600)
print(f'\n⏱️ Total: {time.time()-t0:.0f}s')
# Out:
#   rds_to_h5ad (42 test cases)
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#       #  test_id                                   cells × genes          time  peak_mem  out_size
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#   [ 1/42] v4_pbmc3k_raw                              2700 × 13714  ✅  12.74s     1071 MB     53.1 MB
#   [ 2/42] v4_pbmc3k_processed                        2700 × 13714  ✅  14.88s     1207 MB     54.5 MB
#   [ 3/42] v5_pbmc3k_raw                              2700 × 13714  ✅  11.81s      964 MB     26.9 MB
#   [ 4/42] v5_pbmc3k_processed                        2700 × 13714  ✅  14.53s     1169 MB     54.5 MB
#   [ 5/42] v4_stxKidney_raw                           1438 × 31053  ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 6/42] v5_stxKidney_raw                           1438 × 31053  ✅  13.09s     1323 MB     93.3 MB
#   [ 7/42] v4_celegans_raw                            6188 × 20222  ✅  13.33s     1274 MB    116.6 MB
#   [ 8/42] v4_celegans_processed                      6188 × 20222  ✅  14.61s     1388 MB    119.8 MB
#   [ 9/42] v5_celegans_raw                            6188 × 20222  ✅  11.60s     1083 MB     59.4 MB
#   [10/42] v5_celegans_processed                      6188 × 20222  ✅  15.88s     1532 MB    119.8 MB
#   [11/42] v4_cbmc_raw                                8617 × 20501  ✅  14.07s     1710 MB    190.5 MB
#   [12/42] v4_cbmc_processed                          8617 × 20501  ✅  16.84s     1880 MB    194.8 MB
#   [13/42] v5_cbmc_raw                                8617 × 20501  ✅  12.68s     1336 MB     96.0 MB
#   [14/42] v5_cbmc_processed                          8617 × 20501  ✅  16.59s     1898 MB    194.8 MB
#   [15/42] v4_ifnb_raw                               13999 × 14053  ✅  15.91s     1677 MB    225.8 MB
#   [16/42] v4_ifnb_processed                         13999 × 14053  ✅  19.23s     2076 MB    232.7 MB
#   [17/42] v5_ifnb_raw                               13999 × 14053  ✅  13.89s     1427 MB    113.6 MB
#   [18/42] v5_ifnb_processed                         13999 × 14053  ✅  18.64s     2286 MB    232.7 MB
#   [19/42] v4_panc8_raw                              14890 × 34363  ✅  32.86s     4850 MB   1188.0 MB
#   [20/42] v4_panc8_processed                        14890 × 34363  ✅  35.53s     5191 MB   1195.6 MB
#   [21/42] v5_panc8_raw                              14890 × 34363  ✅  28.61s     3819 MB    595.3 MB
#   [22/42] v5_panc8_processed                        14890 × 34363  ✅  40.66s     6326 MB   1195.6 MB
#   [23/42] v4_thp1_raw                               20729 × 18649  ✅  42.67s     6611 MB   1595.8 MB
#   [24/42] v4_thp1_processed                         20729 × 18649  ✅  48.72s     6985 MB   1606.3 MB
#   [25/42] v5_thp1_raw                               20729 × 18649  ✅  29.54s     4836 MB    799.8 MB
#   [26/42] v5_thp1_processed                         20729 × 18649  ✅  50.44s     8206 MB   1606.4 MB
#   [27/42] v4_bmcite_raw                             30672 × 17009  ✅  28.10s     3143 MB    640.0 MB
#   [28/42] v4_bmcite_processed                       30672 × 17009  ✅  34.00s     4329 MB    655.6 MB
#   [29/42] v5_bmcite_raw                             30672 × 17009  ✅  24.90s     2414 MB    315.1 MB
#   [30/42] v5_bmcite_processed                       30672 × 17009  ✅  31.84s     4325 MB    642.2 MB
#   [31/42] v4_pbmcsca_raw                            31021 × 33694  ✅  27.04s     3022 MB    637.2 MB
#   [32/42] v4_pbmcsca_processed                      31021 × 33694  ✅  30.95s     4088 MB    653.5 MB
#   [33/42] v5_pbmcsca_raw                            31021 × 33694  ✅  22.53s     2439 MB    321.5 MB
#   [34/42] v5_pbmcsca_processed                      31021 × 33694  ✅  30.61s     4387 MB    653.5 MB
#   [35/42] v4_hcabm40k_raw                           40000 × 17369  ✅  29.65s     3986 MB    927.8 MB
#   [36/42] v4_hcabm40k_processed                     40000 × 17369  ✅  38.15s     4959 MB    949.3 MB
#   [37/42] v5_hcabm40k_raw                           40000 × 17369  ✅  23.79s     3167 MB    465.9 MB
#   [38/42] v5_hcabm40k_processed                     40000 × 17369  ✅  38.20s     5864 MB    949.3 MB
#   [39/42] v4_ssHippo_raw                            53173 × 23264  ✅  25.81s     2631 MB    516.6 MB
#   [40/42] v4_ssHippo_processed                      53173 × 23264  ✅  29.25s     4826 MB    542.8 MB
#   [41/42] v5_ssHippo_raw                            53173 × 23264  ✅  19.28s     2141 MB    260.4 MB
#   [42/42] v5_ssHippo_processed                      53173 × 23264  ✅  29.16s     4305 MB    542.8 MB
#
#   h5ad_to_rds (13 test cases)
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#       #  test_id                                   cells × genes          time  peak_mem  out_size
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#   [ 1/13] scanpy_pbmc3k                              2700 × 32738  ✅  12.48s      960 MB      9.8 MB
#   [ 2/13] scanpy_pbmc3k_processed                    2638 × 1838   ✅  25.00s     1192 MB     41.1 MB
#   [ 3/13] scvelo_pancreas                            3696 × 27998  ✅  28.70s     1411 MB     40.0 MB
#   [ 4/13] scvelo_dentategyrus                        2930 × 13913  ✅  20.09s     1136 MB     17.3 MB
#   [ 5/13] squidpy_imc                                4668 × 34     ✅  10.87s      888 MB      1.5 MB
#   [ 6/13] squidpy_mibitof                            3309 × 36     ✅  15.38s      990 MB      2.1 MB
#   [ 7/13] squidpy_visium_hne                         2688 × 18078  ✅  39.12s     1798 MB     73.6 MB
#   [ 8/13] cellxgene_pbmc_15k                        14783 × 17222  ✅  37.20s     1576 MB     68.3 MB
#   [ 9/13] squidpy_seqfish                           19416 × 351    ✅  14.77s     1023 MB      6.5 MB
#   [10/13] cellxgene_heart_23k                       23483 × 32330  ✅  62.58s     2739 MB    161.3 MB
#   [11/13] cellxgene_brain_40k                       40165 × 58232  ✅ 319.74s    10650 MB    994.7 MB
#   [12/13] squidpy_slideseqv2                        41786 × 4000   ✅  24.99s     1358 MB     21.2 MB
#   [13/13] squidpy_merfish                           73655 × 161    ✅  22.66s     1287 MB     33.1 MB
#
#   📊 zellkonverter: 54/55 success, 1 failed, 0 skipped
#   💾 Saved: /benchmark/results/zellkonverter.json
#
# ⏱️ Total: 5013s

# %% [markdown]
# ---
# ## Step 7: Benchmark — anndataR
#
# R/Bioconductor native AnnData interface. Supports both directions.

# %%
t0 = time.time()
all_results['anndataR'] = run_tool_benchmark('anndataR', runs=3, timeout=600)
print(f'\n⏱️ Total: {time.time()-t0:.0f}s')
# Out:
#   rds_to_h5ad (42 test cases)
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#       #  test_id                                   cells × genes          time  peak_mem  out_size
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#   [ 1/42] v4_pbmc3k_raw                              2700 × 13714  ✅   5.72s      647 MB     53.5 MB
#   [ 2/42] v4_pbmc3k_processed                        2700 × 13714  ✅   7.03s      712 MB     58.0 MB
#   [ 3/42] v5_pbmc3k_raw                              2700 × 13714  ✅   5.27s      586 MB     27.3 MB
#   [ 4/42] v5_pbmc3k_processed                        2700 × 13714  ✅   7.05s      706 MB     58.8 MB
#   [ 5/42] v4_stxKidney_raw                           1438 × 31053  ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 6/42] v5_stxKidney_raw                           1438 × 31053  ✅   6.85s      939 MB     94.0 MB
#   [ 7/42] v4_celegans_raw                            6188 × 20222  ✅   7.95s      862 MB    120.0 MB
#   [ 8/42] v4_celegans_processed                      6188 × 20222  ✅  10.33s     1028 MB    128.9 MB
#   [ 9/42] v5_celegans_raw                            6188 × 20222  ✅   6.79s      793 MB     61.1 MB
#   [10/42] v5_celegans_processed                      6188 × 20222  ✅   9.61s     1028 MB    128.1 MB
#   [11/42] v4_cbmc_raw                                8617 × 20501  ✅  10.42s     1134 MB    191.3 MB
#   [12/42] v4_cbmc_processed                          8617 × 20501  ✅  13.95s     1399 MB    204.2 MB
#   [13/42] v5_cbmc_raw                                8617 × 20501  ✅   8.13s      985 MB     96.9 MB
#   [14/42] v5_cbmc_processed                          8617 × 20501  ✅  12.46s     1279 MB    205.3 MB
#   [15/42] v4_ifnb_raw                               13999 × 14053  ✅   9.91s     1137 MB    227.6 MB
#   [16/42] v4_ifnb_processed                         13999 × 14053  ✅  13.35s     1605 MB    248.1 MB
#   [17/42] v5_ifnb_raw                               13999 × 14053  ✅   9.04s     1054 MB    115.6 MB
#   [18/42] v5_ifnb_processed                         13999 × 14053  ✅  12.58s     1498 MB    248.9 MB
#   [19/42] v4_panc8_raw                              14890 × 34363  ✅  31.19s     4832 MB   1192.4 MB
#   [20/42] v4_panc8_processed                        14890 × 34363  ✅  36.77s     5123 MB   1214.5 MB
#   [21/42] v5_panc8_raw                              14890 × 34363  ✅  24.58s     3628 MB    599.9 MB
#   [22/42] v5_panc8_processed                        14890 × 34363  ✅  48.34s     5136 MB   1216.4 MB
#   [23/42] v4_thp1_raw                               20729 × 18649  ✅  55.11s     5474 MB   1598.6 MB
#   [24/42] v4_thp1_processed                         20729 × 18649  ✅  66.46s     6180 MB   1626.6 MB
#   [25/42] v5_thp1_raw                               20729 × 18649  ✅  26.69s     4739 MB    802.8 MB
#   [26/42] v5_thp1_processed                         20729 × 18649  ✅  46.17s     5952 MB   1627.7 MB
#   [27/42] v4_bmcite_raw                             30672 × 17009  ✅  23.81s     3024 MB    683.4 MB
#   [28/42] v4_bmcite_processed                       30672 × 17009  ✅  29.32s     4046 MB    724.3 MB
#   [29/42] v5_bmcite_raw                             30672 × 17009  ✅  14.05s     2129 MB    322.8 MB
#   [30/42] v5_bmcite_processed                       30672 × 17009  ✅  25.93s     3070 MB    676.6 MB
#   [31/42] v4_pbmcsca_raw                            31021 × 33694  ✅  20.51s     2834 MB    646.5 MB
#   [32/42] v4_pbmcsca_processed                      31021 × 33694  ✅  26.94s     3569 MB    690.4 MB
#   [33/42] v5_pbmcsca_raw                            31021 × 33694  ✅  15.00s     2157 MB    331.0 MB
#   [34/42] v5_pbmcsca_processed                      31021 × 33694  ✅  25.53s     3113 MB    692.2 MB
#   [35/42] v4_hcabm40k_raw                           40000 × 17369  ✅  26.45s     3882 MB    930.2 MB
#   [36/42] v4_hcabm40k_processed                     40000 × 17369  ✅  33.81s     4604 MB    984.0 MB
#   [37/42] v5_hcabm40k_raw                           40000 × 17369  ✅  16.80s     2910 MB    468.6 MB
#   [38/42] v5_hcabm40k_processed                     40000 × 17369  ✅  33.19s     4158 MB    984.9 MB
#   [39/42] v4_ssHippo_raw                            53173 × 23264  ✅  18.40s     2385 MB    519.0 MB
#   [40/42] v4_ssHippo_processed                      53173 × 23264  ✅  26.97s     4109 MB    592.5 MB
#   [41/42] v5_ssHippo_raw                            53173 × 23264  ✅  12.04s     1813 MB    262.9 MB
#   [42/42] v5_ssHippo_processed                      53173 × 23264  ✅  28.50s     3665 MB    593.8 MB
#
#   h5ad_to_rds (13 test cases)
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#       #  test_id                                   cells × genes          time  peak_mem  out_size
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#   [ 1/13] scanpy_pbmc3k                              2700 × 32738  ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 2/13] scanpy_pbmc3k_processed                    2638 × 1838   ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 3/13] scvelo_pancreas                            3696 × 27998  ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 4/13] scvelo_dentategyrus                        2930 × 13913  ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 5/13] squidpy_imc                                4668 × 34     ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 6/13] squidpy_mibitof                            3309 × 36     ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 7/13] squidpy_visium_hne                         2688 × 18078  ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 8/13] cellxgene_pbmc_15k                        14783 × 17222  ✅  23.10s     1498 MB     36.5 MB
#   [ 9/13] squidpy_seqfish                           19416 × 351    ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [10/13] cellxgene_heart_23k                       23483 × 32330  ✅  46.58s     2919 MB     83.9 MB
#   [11/13] cellxgene_brain_40k                       40165 × 58232  ✅ 257.29s    14265 MB    499.9 MB
#   [12/13] squidpy_slideseqv2                        41786 × 4000   ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [13/13] squidpy_merfish                           73655 × 161    ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#
#   📊 anndataR: 44/55 success, 11 failed, 0 skipped
#   💾 Saved: /benchmark/results/anndataR.json
#
# ⏱️ Total: 3657s

# %% [markdown]
# ---
# ## Step 8: Benchmark — convert2anndata
#
# R package from settylab. Only supports RDS→H5AD.

# %%
t0 = time.time()
all_results['convert2anndata'] = run_tool_benchmark('convert2anndata', runs=3, timeout=600)
print(f'\n⏱️ Total: {time.time()-t0:.0f}s')
# Out:
#   rds_to_h5ad (42 test cases)
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#       #  test_id                                   cells × genes          time  peak_mem  out_size
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#   [ 1/42] v4_pbmc3k_raw                              2700 × 13714  ❌ [2026-02-11 15:29:59] Input object class: Seurat
# [2026-02-11 15:29:59] Converti
#   [ 2/42] v4_pbmc3k_processed                        2700 × 13714  ❌ [2026-02-11 15:30:12] Input object class: Seurat
# [2026-02-11 15:30:12] Converti
#   [ 3/42] v5_pbmc3k_raw                              2700 × 13714  ❌ [2026-02-11 15:30:25] Input object class: Seurat
# [2026-02-11 15:30:25] Converti
#   [ 4/42] v5_pbmc3k_processed                        2700 × 13714  ❌ [2026-02-11 15:30:42] Input object class: Seurat
# [2026-02-11 15:30:42] Converti
#   [ 5/42] v4_stxKidney_raw                           1438 × 31053  ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 6/42] v5_stxKidney_raw                           1438 × 31053  ❌ [2026-02-11 15:31:18] Input object class: Seurat
# [2026-02-11 15:31:18] Converti
#   [ 7/42] v4_celegans_raw                            6188 × 20222  ❌ [2026-02-11 15:31:33] Input object class: Seurat
# [2026-02-11 15:31:33] Converti
#   [ 8/42] v4_celegans_processed                      6188 × 20222  ❌ [2026-02-11 15:31:48] Input object class: Seurat
# [2026-02-11 15:31:48] Converti
#   [ 9/42] v5_celegans_raw                            6188 × 20222  ❌ [2026-02-11 15:32:01] Input object class: Seurat
# [2026-02-11 15:32:01] Converti
#   [10/42] v5_celegans_processed                      6188 × 20222  ✅  21.47s     2177 MB    399.6 MB
#   [11/42] v4_cbmc_raw                                8617 × 20501  ❌ [2026-02-11 15:40:25] Input object class: Seurat
# [2026-02-11 15:40:25] Converti
#   [12/42] v4_cbmc_processed                          8617 × 20501  ❌ [2026-02-11 15:40:39] Input object class: Seurat
# [2026-02-11 15:40:39] Converti
#   [13/42] v5_cbmc_raw                                8617 × 20501  ✅  14.27s     1443 MB    159.0 MB
#   [14/42] v5_cbmc_processed                          8617 × 20501  ✅  23.64s     2845 MB    595.1 MB
#   [15/42] v4_ifnb_raw                               13999 × 14053  ❌ [2026-02-11 15:42:50] Input object class: Seurat
# [2026-02-11 15:42:50] Converti
#   [16/42] v4_ifnb_processed                         13999 × 14053  ❌ [2026-02-11 15:43:04] Input object class: Seurat
# [2026-02-11 15:43:04] Converti
#   [17/42] v5_ifnb_raw                               13999 × 14053  ✅  13.40s     1565 MB    188.4 MB
#   [18/42] v5_ifnb_processed                         13999 × 14053  ✅  25.63s     4086 MB    855.5 MB
#   [19/42] v4_panc8_raw                              14890 × 34363  ❌ [2026-02-11 15:45:28] Input object class: Seurat
# [2026-02-11 15:45:28] Converti
#   [20/42] v4_panc8_processed                        14890 × 34363  ❌ [2026-02-11 15:45:51] Input object class: Seurat
# [2026-02-11 15:45:51] Converti
#   [21/42] v5_panc8_raw                              14890 × 34363  ✅  28.74s     4790 MB    990.5 MB
#   [22/42] v5_panc8_processed                        14890 × 34363  ✅  45.96s     8466 MB   2173.4 MB
#   [23/42] v4_thp1_raw                               20729 × 18649  ❌ [2026-02-11 15:50:05] Input object class: Seurat
# [2026-02-11 15:50:05] Converti
#   [24/42] v4_thp1_processed                         20729 × 18649  ❌ [2026-02-11 15:50:38] Input object class: Seurat
# [2026-02-11 15:50:38] Converti
#   [25/42] v5_thp1_raw                               20729 × 18649  ✅  33.70s     6154 MB   1330.5 MB
#   [26/42] v5_thp1_processed                         20729 × 18649  ✅  59.00s    11098 MB   2946.2 MB
#   [27/42] v4_bmcite_raw                             30672 × 17009  ❌ [2026-02-11 15:55:36] Input object class: Seurat
# [2026-02-11 15:55:36] Converti
#   [28/42] v4_bmcite_processed                       30672 × 17009  ❌ [2026-02-11 15:56:04] Input object class: Seurat
# [2026-02-11 15:56:04] Converti
#   [29/42] v5_bmcite_raw                             30672 × 17009  ✅  23.50s     2918 MB    522.6 MB
#   [30/42] v5_bmcite_processed                       30672 × 17009  ✅  44.58s     8474 MB   2046.9 MB
#   [31/42] v4_pbmcsca_raw                            31021 × 33694  ❌ [2026-02-11 15:59:47] Input object class: Seurat
# [2026-02-11 15:59:47] Converti
#   [32/42] v4_pbmcsca_processed                      31021 × 33694  ❌ [2026-02-11 16:00:10] Input object class: Seurat
# [2026-02-11 16:00:10] Converti
#   [33/42] v5_pbmcsca_raw                            31021 × 33694  ✅  24.29s     2959 MB    531.9 MB
#   [34/42] v5_pbmcsca_processed                      31021 × 33694  ✅  47.04s     8592 MB   2075.8 MB
#   [35/42] v4_hcabm40k_raw                           40000 × 17369  ❌ [2026-02-11 16:04:00] Input object class: Seurat
# [2026-02-11 16:04:00] Converti
#   [36/42] v4_hcabm40k_processed                     40000 × 17369  ❌ [2026-02-11 16:04:31] Input object class: Seurat
# [2026-02-11 16:04:31] Converti
#   [37/42] v5_hcabm40k_raw                           40000 × 17369  ✅  27.92s     3917 MB    773.6 MB
#   [38/42] v5_hcabm40k_processed                     40000 × 17369  ✅  53.47s    10154 MB   2817.5 MB
#   [39/42] v4_ssHippo_raw                            53173 × 23264  ❌ [2026-02-11 16:08:58] Input object class: Seurat
# [2026-02-11 16:08:58] Converti
#   [40/42] v4_ssHippo_processed                      53173 × 23264  ❌ [2026-02-11 16:09:25] Input object class: Seurat
# [2026-02-11 16:09:25] Converti
#   [41/42] v5_ssHippo_raw                            53173 × 23264  ❌ [2026-02-11 16:09:40] Input object class: Seurat
# [2026-02-11 16:09:40] Converti
#   [42/42] v5_ssHippo_processed                      53173 × 23264  ❌ [2026-02-11 16:10:10] Input object class: Seurat
# [2026-02-11 16:10:10] Converti
#   ⏭️  convert2anndata does not support h5ad_to_rds
#
#   📊 convert2anndata: 15/42 success, 27 failed, 0 skipped
#   💾 Saved: /benchmark/results/convert2anndata.json
#
# ⏱️ Total: 2448s

# %% [markdown]
# ---
# ## Step 9: Benchmark — easySCF
#
# R + Python package. Only supports RDS→H5AD (custom H5 format, not standard H5AD).

# %%
t0 = time.time()
all_results['easySCF'] = run_tool_benchmark('easySCF', runs=3, timeout=600)
print(f'\n⏱️ Total: {time.time()-t0:.0f}s')
# Out:
#   rds_to_h5ad (42 test cases)
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#       #  test_id                                   cells × genes          time  peak_mem  out_size
#   ───────────────────────────────────────────────────────────────────────────────────────────────
#   [ 1/42] v4_pbmc3k_raw                              2700 × 13714  ✅   8.32s      670 MB      6.3 MB
#   [ 2/42] v4_pbmc3k_processed                        2700 × 13714  ✅  11.81s      892 MB     16.2 MB
#   [ 3/42] v5_pbmc3k_raw                              2700 × 13714  ✅   7.55s      618 MB      6.3 MB
#   [ 4/42] v5_pbmc3k_processed                        2700 × 13714  ✅  10.32s      816 MB     16.2 MB
#   [ 5/42] v4_stxKidney_raw                           1438 × 31053  ❌ Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching p
#   [ 6/42] v5_stxKidney_raw                           1438 × 31053  ✅   6.56s      697 MB      0.0 MB
#   [ 7/42] v4_celegans_raw                            6188 × 20222  ✅  10.40s      935 MB     15.0 MB
#   [ 8/42] v4_celegans_processed                      6188 × 20222  ✅  16.63s     1369 MB     31.4 MB
#   [ 9/42] v5_celegans_raw                            6188 × 20222  ✅  10.50s      818 MB     13.8 MB
#   [10/42] v5_celegans_processed                      6188 × 20222  ✅  13.10s     1230 MB     30.1 MB
#   [11/42] v4_cbmc_raw                                8617 × 20501  ✅  12.12s     1236 MB     19.9 MB
#   [12/42] v4_cbmc_processed                          8617 × 20501  ✅  20.56s     1868 MB     43.5 MB
#   [13/42] v5_cbmc_raw                                8617 × 20501  ✅  10.42s     1044 MB     19.9 MB
#   [14/42] v5_cbmc_processed                          8617 × 20501  ✅  17.18s     1793 MB     43.5 MB
#   [15/42] v4_ifnb_raw                               13999 × 14053  ✅  15.24s     1361 MB     25.0 MB
#   [16/42] v4_ifnb_processed                         13999 × 14053  ✅  22.69s     2070 MB     61.6 MB
#   [17/42] v5_ifnb_raw                               13999 × 14053  ✅  12.45s     1063 MB     25.0 MB
#   [18/42] v5_ifnb_processed                         13999 × 14053  ✅  20.91s     2048 MB     61.6 MB
#   [19/42] v4_panc8_raw                              14890 × 34363  ✅  41.10s     4660 MB    144.1 MB
#   [20/42] v4_panc8_processed                        14890 × 34363  ✅  46.93s     6462 MB    184.8 MB
#   [21/42] v5_panc8_raw                              14890 × 34363  ✅  30.96s     4062 MB    144.1 MB
#   [22/42] v5_panc8_processed                        14890 × 34363  ✅  44.67s     6227 MB    184.8 MB
#   [23/42] v4_thp1_raw                               20729 × 18649  ✅  47.22s     6361 MB    157.9 MB
#   [24/42] v4_thp1_processed                         20729 × 18649  ✅  63.41s     7743 MB    277.5 MB
#   [25/42] v5_thp1_raw                               20729 × 18649  ✅  39.60s     5278 MB    157.9 MB
#   [26/42] v5_thp1_processed                         20729 × 18649  ✅  59.13s     8271 MB    277.5 MB
#   [27/42] v4_bmcite_raw                             30672 × 17009  ✅  26.66s     2916 MB     90.0 MB
#   [28/42] v4_bmcite_processed                       30672 × 17009  ✅  40.30s     5287 MB    180.5 MB
#   [29/42] v5_bmcite_raw                             30672 × 17009  ✅  18.16s     2364 MB     67.7 MB
#   [30/42] v5_bmcite_processed                       30672 × 17009  ✅  35.61s     4565 MB    159.5 MB
#   [31/42] v4_pbmcsca_raw                            31021 × 33694  ✅  22.80s     2745 MB     73.3 MB
#   [32/42] v4_pbmcsca_processed                      31021 × 33694  ✅  35.97s     5252 MB    130.0 MB
#   [33/42] v5_pbmcsca_raw                            31021 × 33694  ✅  20.59s     2393 MB     73.3 MB
#   [34/42] v5_pbmcsca_processed                      31021 × 33694  ✅  33.13s     4628 MB    130.0 MB
#   [35/42] v4_hcabm40k_raw                           40000 × 17369  ✅  29.77s     3833 MB    101.0 MB
#   [36/42] v4_hcabm40k_processed                     40000 × 17369  ✅  50.09s     6936 MB    219.2 MB
#   [37/42] v5_hcabm40k_raw                           40000 × 17369  ✅  23.82s     3277 MB    101.0 MB
#   [38/42] v5_hcabm40k_processed                     40000 × 17369  ✅  46.12s     5860 MB    219.2 MB
#   [39/42] v4_ssHippo_raw                            53173 × 23264  ✅   9.73s     1000 MB      0.0 MB
#   [40/42] v4_ssHippo_processed                      53173 × 23264  ✅  17.93s     3560 MB      0.0 MB
#   [41/42] v5_ssHippo_raw                            53173 × 23264  ✅   8.38s     1162 MB      0.0 MB
#   [42/42] v5_ssHippo_processed                      53173 × 23264  ✅  15.04s     2047 MB      0.0 MB
#   ⏭️  easySCF does not support h5ad_to_rds
#
#   📊 easySCF: 41/42 success, 1 failed, 0 skipped
#   💾 Saved: /benchmark/results/easySCF.json
#
# ⏱️ Total: 3121s

# %% [markdown]
# ---
# ## Step 10: Build Comparison Table

# %%
# Reload from disk in case some tools were run in previous sessions
for tool in TOOLS:
    p = os.path.join(RESULTS_DIR, f'{tool}.json')
    if os.path.exists(p) and tool not in all_results:
        with open(p) as f: all_results[tool] = json.load(f)

for tool, data in all_results.items():
    s = data['summary']
    print(f'{tool:20s} {s["success"]:3d}/{s["total"]:3d} success  {s["failed"]:2d} failed  {s["skipped"]:2d} skipped')

rows = []
for tool, data in all_results.items():
    for direction in ['rds_to_h5ad', 'h5ad_to_rds']:
        for r in data.get(direction, []):
            rows.append({
                'tool': tool, 'test_id': r['test_id'], 'direction': direction,
                'status': r['status'],
                'time_s': r.get('conversion_time_seconds'),
                'mem_mb': r.get('peak_memory_mb'),
                'size_mb': r.get('output_file_size_mb'),
                'n_cells': r.get('n_cells'), 'n_genes': r.get('n_genes'),
                'scale': r.get('scale',''), 'dataset': r.get('dataset',''),
            })
df = pd.DataFrame(rows)
df_ok = df[df['status']=='success'].copy()
print(f'\nTotal rows: {len(df)}, successful: {len(df_ok)}')
df_ok.head(10)
# Out:
# zellkonverter         54/ 55 success   1 failed   0 skipped
# anndataR              44/ 55 success  11 failed   0 skipped
# convert2anndata       15/ 42 success  27 failed   0 skipped
# easySCF               41/ 42 success   1 failed   0 skipped
# crosscell             55/ 55 success   0 failed   0 skipped
#
# Total rows: 249, successful: 209
#              tool                test_id    direction   status  time_s  \
# 0   zellkonverter          v4_pbmc3k_raw  rds_to_h5ad  success  12.745
# 1   zellkonverter    v4_pbmc3k_processed  rds_to_h5ad  success  14.880
# 2   zellkonverter          v5_pbmc3k_raw  rds_to_h5ad  success  11.812
# 3   zellkonverter    v5_pbmc3k_processed  rds_to_h5ad  success  14.525
# 5   zellkonverter       v5_stxKidney_raw  rds_to_h5ad  success  13.086
# 6   zellkonverter        v4_celegans_raw  rds_to_h5ad  success  13.327
# 7   zellkonverter  v4_celegans_processed  rds_to_h5ad  success  14.613
# 8   zellkonverter        v5_celegans_raw  rds_to_h5ad  success  11.596
# 9   zellkonverter  v5_celegans_processed  rds_to_h5ad  success  15.881
# 10  zellkonverter            v4_cbmc_raw  rds_to_h5ad  success  14.075
#
#     mem_mb  size_mb  n_cells  n_genes   scale          dataset
# 0   1071.3    53.09   2700.0  13714.0   small           pbmc3k
# 1   1207.4    54.46   2700.0  13714.0   small           pbmc3k
# 2    964.0    26.92   2700.0  13714.0   small           pbmc3k
# 3   1169.1    54.46   2700.0  13714.0   small           pbmc3k
# 5   1323.4    93.34   1438.0  31053.0   small        stxKidney
# 6   1273.5   116.56   6188.0  20222.0  medium  celegans.embryo
# 7   1387.6   119.76   6188.0  20222.0  medium  celegans.embryo
# 8   1082.8    59.44   6188.0  20222.0  medium  celegans.embryo
# 9   1531.9   119.76   6188.0  20222.0  medium  celegans.embryo
# 10  1709.5   190.46   8617.0  20501.0  medium             cbmc

# %% [markdown]
# ---
# ## Step 11: Performance Charts
#
# ### 11.1 RDS → H5AD: Conversion Time

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_comparison(direction, metric, ylabel, title):
    sub = df_ok[df_ok['direction']==direction]
    if sub.empty: print(f'No data for {direction}'); return
    pivot = sub.pivot_table(index='test_id', columns='tool', values=metric, aggfunc='first')
    if 'crosscell' in pivot.columns:
        pivot = pivot.sort_values('crosscell', na_position='last')
    fig, ax = plt.subplots(figsize=(14, max(6, len(pivot)*0.35)))
    pivot.plot(kind='barh', ax=ax)
    ax.set_xlabel(ylabel); ax.set_title(title)
    ax.legend(loc='lower right')
    plt.tight_layout(); plt.show()

plot_comparison('rds_to_h5ad', 'time_s', 'Seconds', 'RDS → H5AD: Conversion Time (lower is better)')

# %% [markdown]
# ### 11.2 RDS → H5AD: Peak Memory

# %%
plot_comparison('rds_to_h5ad', 'mem_mb', 'MB', 'RDS → H5AD: Peak Memory (lower is better)')

# %% [markdown]
# ### 11.3 H5AD → RDS: Conversion Time

# %%
plot_comparison('h5ad_to_rds', 'time_s', 'Seconds', 'H5AD → RDS: Conversion Time (lower is better)')

# %% [markdown]
# ### 11.4 H5AD → RDS: Peak Memory

# %%
plot_comparison('h5ad_to_rds', 'mem_mb', 'MB', 'H5AD → RDS: Peak Memory (lower is better)')

# %% [markdown]
# ---
# ## Step 12: Speedup Analysis

# %%
cc = df_ok[df_ok['tool']=='crosscell'].set_index(['test_id','direction'])
for other in ['zellkonverter','anndataR','convert2anndata','easySCF']:
    ot = df_ok[df_ok['tool']==other].set_index(['test_id','direction'])
    m = cc[['time_s','mem_mb']].join(ot[['time_s','mem_mb']], lsuffix='_cc', rsuffix='_other').dropna()
    if m.empty: continue
    m['speedup'] = m['time_s_other']/m['time_s_cc']
    m['mem_ratio'] = m['mem_mb_other']/m['mem_mb_cc']
    print(f'\nCrossCell vs {other} ({len(m)} common tests):')
    print(f'  Time:   {m.speedup.mean():.1f}x avg, {m.speedup.median():.1f}x median (range: {m.speedup.min():.1f}x – {m.speedup.max():.1f}x)')
    print(f'  Memory: {m.mem_ratio.mean():.1f}x avg (CrossCell uses {1/m.mem_ratio.mean():.0%} of {other} memory)')
# Out:
# CrossCell vs zellkonverter (54 common tests):
#   Time:   6.7x avg, 3.1x median (range: 1.0x – 37.1x)
#   Memory: 4.3x avg (CrossCell uses 23% of zellkonverter memory)
#
# CrossCell vs anndataR (44 common tests):
#   Time:   3.9x avg, 2.7x median (range: 0.9x – 16.6x)
#   Memory: 1.9x avg (CrossCell uses 54% of anndataR memory)
#
# CrossCell vs convert2anndata (15 common tests):
#   Time:   5.1x avg, 4.1x median (range: 2.1x – 11.0x)
#   Memory: 2.8x avg (CrossCell uses 35% of convert2anndata memory)
#
# CrossCell vs easySCF (41 common tests):
#   Time:   5.6x avg, 3.4x median (range: 1.1x – 23.8x)
#   Memory: 2.1x avg (CrossCell uses 47% of easySCF memory)

# %% [markdown]
# ---
# ## Step 13: Scaling Analysis
#
# Conversion time vs dataset size (number of cells).

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for ax, d, title in zip(axes, ['rds_to_h5ad','h5ad_to_rds'], ['RDS → H5AD','H5AD → RDS']):
    sub = df_ok[df_ok['direction']==d]
    for tool in sub['tool'].unique():
        t = sub[sub['tool']==tool].sort_values('n_cells')
        ax.scatter(t['n_cells'], t['time_s'], label=tool, alpha=0.7, s=30)
    ax.set_xlabel('Number of cells'); ax.set_ylabel('Time (s)'); ax.set_title(title)
    ax.legend(fontsize=8); ax.set_xscale('log'); ax.set_yscale('log')
plt.suptitle('Conversion Time vs Dataset Size', fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## Step 14: Success Rate Summary

# %%
srows = []
for tool, data in all_results.items():
    for d in ['rds_to_h5ad','h5ad_to_rds']:
        entries = data.get(d,[])
        tot = len(entries)
        ok = sum(1 for e in entries if e['status']=='success')
        fa = sum(1 for e in entries if e['status']=='failed')
        sk = sum(1 for e in entries if e['status']=='skipped')
        srows.append({'tool':tool,'direction':d,'total':tot,'success':ok,'failed':fa,'skipped':sk,
                      'rate': f'{ok/tot*100:.0f}%' if tot>0 else 'N/A'})
pd.DataFrame(srows)

# %% [markdown]
# ---
# ## Step 15: Export Results
#
# Save combined results with tool versions for archival / Zenodo.

# %%
versions = {'timestamp': datetime.now().isoformat()}
rc, out, _ = run(['crosscell','--version'])
versions['crosscell'] = out.strip() if rc==0 else 'unknown'
rc, out, _ = run_r('cat(R.version.string)')
versions['R'] = out.strip() if rc==0 else 'unknown'
for pkg in ['Seurat','zellkonverter','anndataR','convert2anndata','easySCFr']:
    rc, out, _ = run_r(f"cat(as.character(packageVersion('{pkg}')))")
    versions[pkg] = out.strip() if rc==0 else 'N/A'
versions['anndata_python'] = anndata.__version__
versions['python'] = sys.version.split()[0]

export = {'versions': versions, 'test_matrix_summary': matrix['summary'], 'results': all_results}
export_path = os.path.join(RESULTS_DIR, 'benchmark_combined.json')
with open(export_path, 'w') as f:
    json.dump(export, f, indent=2, ensure_ascii=False)
print(f'✅ Saved: {export_path} ({os.path.getsize(export_path)/1024:.0f} KB)')
print(json.dumps(versions, indent=2))

# %% [markdown]
# ---
# ## Step 16: Files for Zenodo Upload

# %%
print('Files to upload to Zenodo:')
print('='*50)
for f in sorted(glob.glob(os.path.join(RESULTS_DIR, '*.json'))):
    size = os.path.getsize(f)/1024
    print(f'  {os.path.basename(f):40s} {size:8.1f} KB')
print(f'\nSuggested metadata:')
print(f'  Title: CrossCell Performance Benchmark Results')
print(f'  Date: {datetime.now().strftime("%Y-%m-%d")}')
print(f'  Keywords: single-cell, format conversion, benchmark, Seurat, AnnData')
